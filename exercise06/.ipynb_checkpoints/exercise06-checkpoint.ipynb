# %% [markdown]
# ### Exercise 6 - Model Predictive Control
#
# In this exercise, we consider a Model Predicitve Control (MPC)  approach to control the inverted pendulum on cart.
# The system dynamics are given via the ODE:
# \begin{equation}\label{eq:dynamics}
# \begin{aligned}
# \dot{p} =& v \\
# \dot{\theta} =& \omega \\
# \dot{v} =  &
# -\frac{m l \sin(\theta)\omega^2 + m g \cos(\theta)\sin(\theta)+F}{ M + m - m\cos(\theta)\cos(\theta)}\\
# \dot{\omega} =& -\frac{m l \cos(\theta)\sin(\theta) \omega^2 + F \cos(\theta)+(M+m)g \sin(\theta)}{l(M + m - m\cos(\theta)\cos(\theta))},
# \end{aligned}
# \end{equation}
# where $\theta$ is the angle describing the orientation of the pendulum, $\omega$ is its angular velocity and $p$ and $v$ are position and velocity of the cart.
# Here,  $ M, m, g$ and $ l $ are parameters of the model describing the mass of the cart, the mass of the ball, the gravity constant and the length of the rod respectively.
# The force $ F $ is the control action.
#
# The goal is to design a feedback policy capable of swinging up the pendulum starting from $\theta = \pi$.
#
#
# Consider the following optimal control problem,
# <img src="imgs/ocp.png" alt="nlp" width="350"/>
#
#
# where $F(s,a)$ describes the discretized dynamics obtained by applying three step of the explicit RK4 integrator with integration interval $h=0.05$.

# %%
import numpy as np
from casadi import *
from model import Model
from utils import integrate_RK4
from get_LQR_gain import get_LQR_gain

# continuous dynamics
ns = 4
na = 1

# constants
M = 1. # mass of the cart [kg]
m = 0.1 # mass of the ball [kg]
g = 9.81 # length of the rod [m]
l = 0.8 # gravity constant [m/s^2]

# set up states & controls
x1      = SX.sym('x1')
theta   = SX.sym('theta')
v1      = SX.sym('v1')
dtheta  = SX.sym('dtheta')  

s_expr = vertcat(x1, theta, v1, dtheta)

# controls
F = SX.sym('F')
a_expr = vertcat(F)

# dynamics
cos_theta = cos(theta)
sin_theta = sin(theta)

denominator = M + m - m*cos_theta*cos_theta
s_dot = vertcat(v1,
                dtheta,
                (-m*l*sin_theta*dtheta*dtheta + m*g*cos_theta*sin_theta+F)/denominator,
                (-m*l*cos_theta*sin_theta*dtheta*dtheta + F*cos_theta+(M+m)*g*sin_theta)/(l*denominator)
                )

# discrete dynamics
dt = 0.05
n_steps = 5
F_discrete = integrate_RK4(s_expr, a_expr, s_dot, dt, n_steps)

# steady state
s_steady_state = np.zeros((ns, 1))
a_steady_state = np.zeros((na, 1))

model = Model(s_expr, a_expr, F_discrete, s_steady_state, a_steady_state)

a_max = 35
a_min = -a_max

Q = np.diag([1e3, 1e4, 1e-2, 1e-2])
R = np.diag([1])

A = model.J_x(model.s_steady_state, model.a_steady_state).full()
B = model.J_u(model.s_steady_state, model.a_steady_state).full()

(K, P) = get_LQR_gain(A, B, Q, R)

stage_cost_expr = s_expr.T @ Q @ s_expr + a_expr.T @ R @ a_expr
terminal_cost_expr = s_expr.T @ P @ s_expr

stage_cost = Function('stage_cost', [s_expr, a_expr], [stage_cost_expr])
terminal_cost = Function('terminal_cost', [s_expr], [terminal_cost_expr])

# %% [markdown]
# ### 6.1 OCP formulation
#
# Complete the following template to obtain a solver for the above OCP, which is parametric in the initial state $ \bar s_0$.

# %%
class  OCPsolver:

    def __init__(self, model, stage_cost, terminal_cost, N, a_max, a_min):

        self.N = N
        self.model = model

        ns = model.ns
        na = model.na

        # setup OCP

        # optimization variables
        s_traj = SX.sym('s_traj', ns*(N+1), 1)
        a_traj = SX.sym('a_traj', na*N, 1)

        # split trajectories to obtain x and u for each stage
        s_ns = vertsplit(s_traj, np.arange(0, ns*(N+1)+1, ns))
        a_ns = vertsplit(a_traj, np.arange(0, na*N+1, na))

        # initial state (will be a parameter of the optimization problem)
        s0_bar = SX.sym('s0_bar', ns, 1)

        cost = 0

        # initial constraint
        constraints = [s_ns[0] - s0_bar]

        for n in range(N):
            s0 = s_ns[n]
            a0 = a_ns[n]
            s1 = s_ns[n+1]
            
            f0 = model.f(s0, a0)

            # add stage cost to objective
            cost += stage_cost(s0, a0)

            # add continuity contraint
            constraints += [s1-f0] 
        
        # add terminal cost
        cost += terminal_cost(s1)

        # continuity constraints and bounds on u
        constraints = vertcat(*constraints, a_traj)

        # set upper and lower bounds 
        # zeros for continuity constraints, a_max/a_min fro control bounds
        self.ubg = vertcat(np.zeros((ns*(N+1))), a_max*np.ones((N*na)))
        self.lbg = vertcat(np.zeros((ns*(N+1))), a_min*np.ones((N*na)))

        self.ocp = {'f': cost, 'x': vertcat(s_traj, a_traj), 'g': constraints, 'p':s0_bar}
        self.solver = nlpsol('solver', 'ipopt', self.ocp)

        # initialize current solution guess
        self.s_current = np.zeros((ns*(N+1), 1))
        self.a_current = np.zeros((na*N, 1))


    def solve(self, s0, s_traj_init=None, a_traj_init=None):

        if s_traj_init is not None:
            self.s_current = s_traj_init

        if a_traj_init is not None:
            self.a_current = a_traj_init

        # solve the NLP
        sol = self.solver(x0=vertcat(self.s_current, self.a_current), lbg=self.lbg, ubg=self.ubg, p=s0)
        
        w_opt = sol['x'].full()

        s_opt = w_opt[:(self.N+1)*self.model.ns]
        a_opt = w_opt[(self.N+1)*self.model.ns:]

        cost = sol['f'].full()

        self.s_current = s_opt
        self.a_current = a_opt

#         FILL IN YOUR CODE HERE
        a0_opt = a_opt[:self.model.na]
        return a0_opt


    def reset(self):
        self.s_current = np.zeros((self.model.ns*(self.N+1), 1))
        self.a_current = np.zeros((self.model.na*self.N, 1))

# %% [markdown]
# ### 6.2 Closed Loop Simulation
#
# Complete the following template to obtain a closed loop simulation of the system.
#
# Do you expect the closed loop trajectories obtained with the MPC approach to differ from the trajectories you'd obtain by solving a single open loop OCP? Why?

# %%
from plot_utils import plot_trajectories_pendulum_on_cart
import matplotlib.pyplot as plt

N_steps = 100
N_horizon = 20

ocp_solver = OCPsolver(model, stage_cost, terminal_cost, N_horizon, a_max, -a_max)

s_traj = np.zeros((ns, N_steps+1))
a_traj = np.zeros((na, N_steps))

s0 = np.array([0, np.pi, 0, 0])

# closed-loop simulation
s_traj[:, 0] = s0

for n in range(N_steps):
    s = s_traj[:, n]
#         FILL IN YOUR CODE HERE
    a = ocp_solver.solve(s)

    a_traj[:, n] = a
    s_traj[:, [n+1]] = model.simulate(s, a)
# Out:
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...
-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240  5.7933627e+05 2.86e-01 5.62e+03  -1.0 1.04e+01    -  4.18e-01 4.63e-02f  1
#  241  5.7688688e+05 9.63e-03 3.13e+02  -1.0 6.82e+00    -  7.38e-03 1.00e+00f  1
#  242  5.7687889e+05 9.35e-03 3.04e+02  -1.0 9.66e+00    -  1.00e+00 2.90e-02f  1
#  243  5.7679067e+05 1.16e-03 4.10e+01  -1.0 9.42e+00    -  1.41e-01 1.00e+00f  1
#  244  5.7678956e+05 3.21e-04 1.14e+01  -1.7 2.14e-01    -  1.00e+00 7.23e-01f  1
#  245  5.7678907e+05 5.58e-08 1.48e-03  -2.5 5.94e-02    -  1.00e+00 1.00e+00f  1
#  246  5.7678904e+05 2.51e-12 2.85e-08  -5.7 1.30e-04    -  1.00e+00 1.00e+00f  1
#  247  5.7678904e+05 1.78e-15 7.28e-11  -8.6 8.86e-08    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 247
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.7678904045995011e+05    5.7678904045995011e+05
# Dual infeasibility......:   7.2759576141834259e-11    7.2759576141834259e-11
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Complementarity.........:   2.5098908315207534e-09    2.5098908315207534e-09
# Overall NLP error.......:   1.2325999769336967e-09    2.5098908315207534e-09
#
#
# Number of objective function evaluations             = 568
# Number of objective gradient evaluations             = 229
# Number of equality constraint evaluations            = 568
# Number of inequality constraint evaluations          = 568
# Number of equality constraint Jacobian evaluations   = 249
# Number of inequality constraint Jacobian evaluations = 249
# Number of Lagrangian Hessian evaluations             = 247
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.180
# Total CPU secs in NLP function evaluations           =      0.244
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.58ms (  2.77us)   1.58ms (  2.79us)       568
#        nlp_g  |  25.93ms ( 45.66us)  26.27ms ( 46.25us)       568
#     nlp_grad  | 137.00us (137.00us) 136.94us (136.94us)         1
#   nlp_grad_f  | 868.00us (  3.77us) 900.06us (  3.91us)       230
#   nlp_hess_l  | 160.31ms (651.68us) 161.09ms (654.84us)       246
#    nlp_jac_g  |  53.94ms (215.77us)  54.10ms (216.39us)       250
#        total  | 495.31ms (495.31ms) 495.88ms (495.88ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  5.7678904e+05 2.17e+00 7.92e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.4931836e+05 1.54e+00 2.88e+01  -1.0 5.12e+01    -  9.25e-02 2.93e-01f  1
#    2  5.3968039e+05 1.24e+00 2.30e+01  -1.0 1.82e+01    -  7.96e-02 1.91e-01f  1
#    3  5.1980994e+05 6.99e-01 1.20e+01  -1.0 2.46e+01    -  1.79e-01 4.38e-01f  1
#    4  5.1381130e+05 5.70e-01 9.70e+00  -1.0 2.69e+01    -  6.23e-01 1.85e-01f  1
#    5  4.8937584e+05 1.66e-01 2.56e+01  -1.0 4.11e+01    -  1.90e-01 7.09e-01f  1
#    6  4.8422032e+05 1.13e-01 1.84e+01  -1.0 2.64e+01    -  7.76e-01 3.21e-01f  1
#    7  4.7847706e+05 8.30e-03 2.61e+00  -1.0 7.57e+00    -  8.82e-01 1.00e+00f  1
#    8  4.7739630e+05 2.31e-03 4.57e-01  -1.0 3.83e+00    -  1.00e+00 8.75e-01f  1
#    9  4.7699319e+05 4.93e-04 1.63e-02  -1.7 2.18e+00    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.7688620e+05 5.17e-05 1.43e-03  -2.5 6.73e-01    -  1.00e+00 1.00e+00f  1
#   11  4.7686895e+05 1.94e-06 4.03e-05  -3.8 1.42e-01    -  1.00e+00 1.00e+00f  1
#   12  4.7686800e+05 6.43e-09 1.21e-07  -5.7 8.02e-03    -  1.00e+00 1.00e+00h  1
#   13  4.7686799e+05 5.35e-13 1.00e-11  -8.6 6.56e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 13
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.5895898000729142e+02    4.7686799119338189e+05
# Dual infeasibility......:   1.0015099860538612e-11    6.2926728293672531e-09
# Constraint violation....:   5.3468340865947539e-13    5.3468340865947539e-13
# Complementarity.........:   2.5365482637438153e-09    1.5937602781707032e-06
# Overall NLP error.......:   2.5365482637438153e-09    1.5937602781707032e-06
#
#
# Number of objective function evaluations             = 14
# Number of objective gradient evaluations             = 14
# Number of equality constraint evaluations            = 14
# Number of inequality constraint evaluations          = 14
# Number of equality constraint Jacobian evaluations   = 14
# Number of inequality constraint Jacobian evaluations = 14
# Number of Lagrangian Hessian evaluations             = 13
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.008
# Total CPU secs in NLP function evaluations           =      0.012
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  48.00us (  3.43us)  44.84us (  3.20us)        14
#        nlp_g  | 680.00us ( 48.57us) 695.28us ( 49.66us)        14
#     nlp_grad  | 125.00us (125.00us) 124.68us (124.68us)         1
#   nlp_grad_f  |  54.00us (  3.60us)  56.34us (  3.76us)        15
#   nlp_hess_l  |   8.21ms (631.92us)   8.22ms (632.53us)        13
#    nlp_jac_g  |   3.05ms (203.60us)   3.07ms (204.35us)        15
#        total  |  22.99ms ( 22.99ms)  23.03ms ( 23.03ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  4.7686799e+05 2.07e+00 5.54e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  4.5123341e+05 1.52e+00 3.02e+01  -1.0 5.70e+01    -  8.39e-02 2.64e-01f  1
#    2  4.0795661e+05 8.29e-02 9.12e+00  -1.0 1.68e+01    -  8.62e-02 1.00e+00f  1
#    3  3.9895963e+05 5.41e-02 5.36e+00  -1.0 2.19e+01    -  2.46e-01 4.11e-01f  1
#    4  3.8968756e+05 3.04e-02 1.10e+01  -1.0 2.28e+01    -  5.63e-01 1.00e+00f  1
#    5  3.8245914e+05 3.10e-02 5.67e+00  -1.0 2.72e+01    -  7.01e-01 6.18e-01f  1
#    6  3.8116639e+05 8.02e-03 5.75e-01  -1.0 1.02e+01    -  7.91e-01 8.72e-01f  1
#    7  3.8080106e+05 1.30e-03 3.60e-02  -1.0 6.17e+00    -  1.00e+00 1.00e+00f  1
#    8  3.8044656e+05 5.41e-04 1.02e-02  -1.7 1.70e+00    -  1.00e+00 1.00e+00f  1
#    9  3.8035668e+05 3.75e-05 9.82e-04  -2.5 5.40e-01    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.8034197e+05 1.47e-06 3.08e-05  -3.8 1.20e-01    -  1.00e+00 1.00e+00f  1
#   11  3.8034116e+05 4.95e-09 9.73e-08  -5.7 6.94e-03    -  1.00e+00 1.00e+00h  1
#   12  3.8034115e+05 4.65e-13 9.14e-12  -8.6 6.18e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.1602342048181276e+02    3.8034115330646758e+05
# Dual infeasibility......:   9.1446850092324894e-12    5.6460516392631796e-09
# Constraint violation....:   4.6451731350316550e-13    4.6451731350316550e-13
# Complementarity.........:   2.5334599161308616e-09    1.5641922600982779e-06
# Overall NLP error.......:   2.5334599161308616e-09    1.5641922600982779e-06
#
#
# Number of objective function evaluations             = 13
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 13
# Number of inequality constraint evaluations          = 13
# Number of equality constraint Jacobian evaluations   = 13
# Number of inequality constraint Jacobian evaluations = 13
# Number of Lagrangian Hessian evaluations             = 12
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.008
# Total CPU secs in NLP function evaluations           =      0.011
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  42.00us (  3.23us)  41.17us (  3.17us)        13
#        nlp_g  | 627.00us ( 48.23us) 629.29us ( 48.41us)        13
#     nlp_grad  | 130.00us (130.00us) 129.04us (129.04us)         1
#   nlp_grad_f  |  56.00us (  4.00us)  53.59us (  3.83us)        14
#   nlp_hess_l  |   7.60ms (633.75us)   7.62ms (634.71us)        12
#    nlp_jac_g  |   2.90ms (207.00us)   2.93ms (209.04us)        14
#        total  |  21.59ms ( 21.59ms)  21.54ms ( 21.54ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  3.8034115e+05 1.77e+00 3.92e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.5845330e+05 1.35e+00 3.12e+01  -1.0 6.34e+01    -  7.95e-02 2.37e-01f  1
#    2  3.1741389e+05 1.60e-01 1.68e+01  -1.0 2.63e+01    -  7.58e-02 1.00e+00f  1
#    3  3.0802585e+05 1.52e-02 5.27e+00  -1.0 1.63e+01    -  3.09e-01 1.00e+00f  1
#    4  2.9996288e+05 3.17e-02 1.16e+00  -1.0 2.27e+01    -  5.26e-01 1.00e+00f  1
#    5  2.9562901e+05 2.30e-02 2.86e-01  -1.0 2.18e+01    -  7.39e-01 4.39e-01f  1
#    6  2.9493927e+05 7.60e-03 3.15e+00  -1.0 1.23e+01    -  7.57e-01 1.00e+00f  1
#    7  2.9385074e+05 2.22e-03 4.70e-01  -1.0 6.30e+00    -  1.00e+00 9.42e-01f  1
#    8  2.9356974e+05 6.12e-04 1.08e-02  -1.7 2.09e+00    -  1.00e+00 1.00e+00f  1
#    9  2.9349370e+05 3.81e-05 7.46e-04  -2.5 5.17e-01    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.9348138e+05 1.29e-06 2.84e-05  -3.8 1.14e-01    -  1.00e+00 1.00e+00f  1
#   11  2.9348070e+05 4.12e-09 8.80e-08  -5.7 6.44e-03    -  1.00e+00 1.00e+00h  1
#   12  2.9348069e+05 3.84e-13 8.37e-12  -8.6 5.77e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.0153454303758252e+02    2.9348069162007747e+05
# Dual infeasibility......:   8.3701934272539802e-12    4.8979480877755761e-09
# Constraint violation....:   3.8369307731045410e-13    3.8369307731045410e-13
# Complementarity.........:   2.5310008295495421e-09    1.4810542648734917e-06
# Overall NLP error.......:   2.5310008295495421e-09    1.4810542648734917e-06
#
#
# Number of objective function evaluations             = 13
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 13
# Number of inequality constraint evaluations          = 13
# Number of equality constraint Jacobian evaluations   = 13
# Number of inequality constraint Jacobian evaluations = 13
# Number of Lagrangian Hessian evaluations             = 12
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.008
# Total CPU secs in NLP function evaluations           =      0.011
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  50.00us (  3.85us)  61.26us (  4.71us)        13
#        nlp_g  | 642.00us ( 49.38us) 644.51us ( 49.58us)        13
#     nlp_grad  | 125.00us (125.00us) 123.52us (123.52us)         1
#   nlp_grad_f  |  57.00us (  4.07us)  58.04us (  4.15us)        14
#   nlp_hess_l  |   7.83ms (652.75us)   7.83ms (652.63us)        12
#    nlp_jac_g  |   2.95ms (210.64us)   2.96ms (211.29us)        14
#        total  |  23.63ms ( 23.63ms)  23.63ms ( 23.63ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.9348069e+05 1.56e+00 3.54e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.7615911e+05 1.23e+00 3.22e+01  -1.0 6.99e+01    -  8.96e-02 2.15e-01f  1
#    2  2.3230264e+05 5.19e-01 1.26e+01  -1.0 4.27e+01    -  3.33e-02 1.00e+00f  1
#    3  2.2510060e+05 1.69e-02 6.62e-01  -1.0 1.33e+01    -  5.39e-01 1.00e+00f  1
#    4  2.2227043e+05 1.34e-02 2.19e+00  -1.0 1.36e+01    -  7.90e-01 1.00e+00f  1
#    5  2.2133650e+05 6.67e-03 2.40e-01  -1.0 1.14e+01    -  7.50e-01 1.00e+00f  1
#    6  2.2125738e+05 3.49e-04 3.90e-02  -1.0 4.20e+00    -  1.00e+00 1.00e+00f  1
#    7  2.2102030e+05 3.61e-04 7.59e-03  -1.7 1.44e+00    -  1.00e+00 1.00e+00f  1
#    8  2.2095232e+05 3.42e-05 8.44e-04  -3.8 5.35e-01    -  9.97e-01 1.00e+00f  1
#    9  2.2095071e+05 1.62e-07 3.51e-06  -3.8 5.20e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.2095022e+05 1.81e-09 4.66e-08  -5.7 4.09e-03    -  1.00e+00 1.00e+00h  1
#   11  2.2095022e+05 2.63e-13 6.80e-12  -8.6 4.87e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 11
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.1416306394024480e+02    2.2095021536568351e+05
# Dual infeasibility......:   6.7998939812241588e-12    3.6276485530154955e-09
# Constraint violation....:   2.6290081223123707e-13    2.6290081223123707e-13
# Complementarity.........:   2.5254569785487557e-09    1.3472960577373551e-06
# Overall NLP error.......:   2.5254569785487557e-09    1.3472960577373551e-06
#
#
# Number of objective function evaluations             = 12
# Number of objective gradient evaluations             = 12
# Number of equality constraint evaluations            = 12
# Number of inequality constraint evaluations          = 12
# Number of equality constraint Jacobian evaluations   = 12
# Number of inequality constraint Jacobian evaluations = 12
# Number of Lagrangian Hessian evaluations             = 11
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.008
# Total CPU secs in NLP function evaluations           =      0.011
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  41.00us (  3.42us)  39.92us (  3.33us)        12
#        nlp_g  | 584.00us ( 48.67us) 587.88us ( 48.99us)        12
#     nlp_grad  | 126.00us (126.00us) 126.11us (126.11us)         1
#   nlp_grad_f  |  55.00us (  4.23us)  51.80us (  3.98us)        13
#   nlp_hess_l  |   7.35ms (668.64us)   7.39ms (671.48us)        11
#    nlp_jac_g  |   2.81ms (215.92us)   2.88ms (221.36us)        13
#        total  |  22.03ms ( 22.03ms)  21.91ms ( 21.91ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.2095022e+05 1.26e+00 3.87e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.7315620e+05 2.24e-01 4.46e+01  -1.0 1.24e+01    -  5.34e-01 1.00e+00f  1
#    2  1.6811697e+05 6.20e-02 1.27e+01  -1.0 1.74e+01    -  9.10e-02 7.23e-01f  1
#    3  1.6639014e+05 1.37e-02 2.23e-01  -1.0 1.13e+01    -  8.60e-01 1.00e+00f  1
#    4  1.6588830e+05 3.18e-03 8.30e-01  -1.0 6.16e+00    -  9.15e-01 1.00e+00f  1
#    5  1.6588420e+05 2.99e-04 1.92e-02  -1.0 2.66e+00    -  1.00e+00 1.00e+00f  1
#    6  1.6567049e+05 4.11e-05 9.13e-02  -2.5 1.07e+00    -  1.00e+00 1.00e+00f  1
#    7  1.6563936e+05 5.20e-06 5.18e-03  -2.5 3.53e-01    -  1.00e+00 1.00e+00f  1
#    8  1.6563046e+05 3.39e-07 3.73e-04  -3.8 8.88e-02    -  1.00e+00 1.00e+00f  1
#    9  1.6562993e+05 1.41e-09 1.44e-06  -5.7 5.69e-03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.6562992e+05 1.13e-13 1.28e-10  -8.6 4.96e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 10
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.5489639656900755e+02    1.6562992047465328e+05
# Dual infeasibility......:   1.2798295756510925e-10    5.9729564144780429e-08
# Constraint violation....:   1.1279865930191590e-13    1.1279865930191590e-13
# Complementarity.........:   2.5441372746789954e-09    1.1873472330388883e-06
# Overall NLP error.......:   2.5441372746789954e-09    1.1873472330388883e-06
#
#
# Number of objective function evaluations             = 11
# Number of objective gradient evaluations             = 11
# Number of equality constraint evaluations            = 11
# Number of inequality constraint evaluations          = 11
# Number of equality constraint Jacobian evaluations   = 11
# Number of inequality constraint Jacobian evaluations = 11
# Number of Lagrangian Hessian evaluations             = 10
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.007
# Total CPU secs in NLP function evaluations           =      0.010
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  35.00us (  3.18us)  38.62us (  3.51us)        11
#        nlp_g  | 519.00us ( 47.18us) 522.07us ( 47.46us)        11
#     nlp_grad  | 119.00us (119.00us) 118.31us (118.31us)         1
#   nlp_grad_f  |  50.00us (  4.17us)  51.94us (  4.33us)        12
#   nlp_hess_l  |   6.51ms (651.00us)   6.54ms (653.57us)        10
#    nlp_jac_g  |   2.59ms (215.58us)   2.62ms (218.20us)        12
#        total  |  20.40ms ( 20.40ms)  20.55ms ( 20.55ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.6562992e+05 1.72e+00 4.42e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.5747433e+05 1.41e+00 2.21e+00  -1.0 2.29e+01    -  4.19e-01 1.79e-01f  1
#    2  1.3142922e+05 2.38e-01 2.21e+01  -1.0 2.36e+01    -  3.26e-02 8.31e-01f  1
#    3  1.2387477e+05 7.68e-03 6.89e+00  -1.0 5.30e+00    -  8.76e-01 1.00e+00f  1
#    4  1.2339743e+05 3.23e-03 1.79e-01  -1.0 6.41e+00    -  9.73e-01 1.00e+00f  1
#    5  1.2325442e+05 1.81e-04 6.34e-02  -1.7 2.00e+00    -  1.00e+00 1.00e+00f  1
#    6  1.2321523e+05 8.82e-06 6.35e-03  -2.5 3.55e-01    -  1.00e+00 1.00e+00f  1
#    7  1.2320867e+05 2.81e-07 2.18e-04  -3.8 7.36e-02    -  1.00e+00 1.00e+00f  1
#    8  1.2320832e+05 9.78e-10 6.61e-07  -5.7 4.22e-03    -  1.00e+00 1.00e+00h  1
#    9  1.2320832e+05 8.62e-14 6.54e-11  -8.6 3.89e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 9
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.0725400522916948e+02    1.2320832016756340e+05
# Dual infeasibility......:   6.5440985963505227e-11    2.6241721225598905e-08
# Constraint violation....:   8.6153306710912148e-14    8.6153306710912148e-14
# Complementarity.........:   2.5297261606169518e-09    1.0144157779199044e-06
# Overall NLP error.......:   2.5297261606169518e-09    1.0144157779199044e-06
#
#
# Number of objective function evaluations             = 10
# Number of objective gradient evaluations             = 10
# Number of equality constraint evaluations            = 10
# Number of inequality constraint evaluations          = 10
# Number of equality constraint Jacobian evaluations   = 10
# Number of inequality constraint Jacobian evaluations = 10
# Number of Lagrangian Hessian evaluations             = 9
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.007
# Total CPU secs in NLP function evaluations           =      0.009
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  35.00us (  3.50us)  35.48us (  3.55us)        10
#        nlp_g  | 500.00us ( 50.00us) 513.60us ( 51.36us)        10
#     nlp_grad  | 148.00us (148.00us) 147.71us (147.71us)         1
#   nlp_grad_f  |  47.00us (  4.27us)  46.05us (  4.19us)        11
#   nlp_hess_l  |   6.25ms (694.22us)   6.31ms (701.50us)         9
#    nlp_jac_g  |   2.36ms (214.64us)   2.37ms (215.45us)        11
#        total  |  18.78ms ( 18.78ms)  18.96ms ( 18.96ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.2320832e+05 1.66e+00 5.35e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.1352471e+05 1.19e+00 3.39e+00  -1.0 2.63e+01    -  3.95e-01 2.84e-01f  1
#    2  9.3155136e+04 2.06e-01 7.37e+00  -1.0 2.47e+01    -  3.48e-02 1.00e+00f  1
#    3  9.0736299e+04 6.17e-04 9.58e-01  -1.0 2.07e+00    -  8.71e-01 1.00e+00f  1
#    4  9.0326064e+04 2.82e-03 4.09e-01  -1.0 7.08e+00    -  9.75e-01 1.00e+00f  1
#    5  9.0235656e+04 1.30e-04 2.51e-02  -1.7 1.46e+00    -  1.00e+00 1.00e+00f  1
#    6  9.0209141e+04 5.62e-06 4.60e-03  -2.5 3.18e-01    -  1.00e+00 1.00e+00f  1
# ...
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.003
# Total CPU secs in NLP function evaluations           =      0.004
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00us (  2.67us)  17.67us (  2.95us)         6
#        nlp_g  | 232.00us ( 38.67us) 236.20us ( 39.37us)         6
#     nlp_grad  | 108.00us (108.00us) 108.16us (108.16us)         1
#   nlp_grad_f  |  28.00us (  4.00us)  25.49us (  3.64us)         7
#   nlp_hess_l  |   2.90ms (579.80us)   2.90ms (580.39us)         5
#    nlp_jac_g  |   1.24ms (177.71us)   1.25ms (177.86us)         7
#        total  |   9.07ms (  9.07ms)   9.07ms (  9.07ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  4.8104962e-02 3.35e-04 7.82e-14  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  4.1970781e-02 3.11e-13 1.36e-07  -1.0 3.50e-04    -  9.93e-01 1.00e+00h  1
#    2  4.1970781e-02 8.67e-19 9.57e-15  -1.7 1.77e-06    -  1.00e+00 1.00e+00h  1
#    3  4.1970781e-02 8.67e-19 1.18e-14  -3.8 7.97e-09    -  1.00e+00 1.00e+00h  1
#    4  4.1970781e-02 4.34e-19 3.55e-15  -5.7 6.21e-11    -  1.00e+00 1.00e+00h  1
#    5  4.1970781e-02 4.34e-19 5.57e-15  -8.6 7.69e-13    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.1970780974698960e-02    4.1970780974698960e-02
# Dual infeasibility......:   5.5727178514125564e-15    5.5727178514125564e-15
# Constraint violation....:   4.3368086899420177e-19    4.3368086899420177e-19
# Complementarity.........:   2.5059035597204799e-09    2.5059035597204799e-09
# Overall NLP error.......:   2.5059035597204799e-09    2.5059035597204799e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 6
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 6
# Number of Lagrangian Hessian evaluations             = 5
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.003
# Total CPU secs in NLP function evaluations           =      0.004
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00us (  2.67us)  16.41us (  2.74us)         6
#        nlp_g  | 217.00us ( 36.17us) 219.23us ( 36.54us)         6
#     nlp_grad  |  93.00us ( 93.00us)  93.36us ( 93.36us)         1
#   nlp_grad_f  |  25.00us (  3.57us)  23.93us (  3.42us)         7
#   nlp_hess_l  |   2.74ms (548.80us)   2.75ms (549.24us)         5
#    nlp_jac_g  |   1.18ms (167.86us)   1.18ms (168.22us)         7
#        total  |   8.61ms (  8.61ms)   8.61ms (  8.61ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  4.1970781e-02 3.19e-04 1.67e-13  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.6618917e-02 3.11e-13 1.36e-07  -1.0 3.50e-04    -  9.93e-01 1.00e+00h  1
#    2  3.6618917e-02 8.67e-19 7.11e-15  -1.7 1.65e-06    -  1.00e+00 1.00e+00h  1
#    3  3.6618917e-02 8.67e-19 1.16e-14  -3.8 7.02e-09    -  1.00e+00 1.00e+00h  1
#    4  3.6618917e-02 8.67e-19 3.55e-15  -5.7 5.48e-11    -  1.00e+00 1.00e+00h  1
#    5  3.6618917e-02 4.34e-19 5.33e-15  -8.6 6.79e-13    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.6618916714447676e-02    3.6618916714447676e-02
# Dual infeasibility......:   5.3290705182007514e-15    5.3290705182007514e-15
# Constraint violation....:   4.3368086899420177e-19    4.3368086899420177e-19
# Complementarity.........:   2.5059035597158423e-09    2.5059035597158423e-09
# Overall NLP error.......:   2.5059035597158423e-09    2.5059035597158423e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 6
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 6
# Number of Lagrangian Hessian evaluations             = 5
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.003
# Total CPU secs in NLP function evaluations           =      0.004
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  14.00us (  2.33us)  15.65us (  2.61us)         6
#        nlp_g  | 215.00us ( 35.83us) 219.19us ( 36.53us)         6
#     nlp_grad  | 101.00us (101.00us) 101.66us (101.66us)         1
#   nlp_grad_f  |  22.00us (  3.14us)  22.94us (  3.28us)         7
#   nlp_hess_l  |   2.62ms (524.60us)   2.63ms (525.61us)         5
#    nlp_jac_g  |   1.14ms (163.00us)   1.14ms (163.37us)         7
#        total  |   8.39ms (  8.39ms)   8.41ms (  8.41ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  3.6618917e-02 3.02e-04 1.87e-13  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.1949593e-02 3.11e-13 1.36e-07  -1.0 3.50e-04    -  9.93e-01 1.00e+00h  1
#    2  3.1949593e-02 4.34e-19 6.04e-15  -1.7 1.52e-06    -  1.00e+00 1.00e+00h  1
#    3  3.1949593e-02 4.34e-19 8.91e-15  -3.8 6.14e-09    -  1.00e+00 1.00e+00h  1
#    4  3.1949593e-02 8.67e-19 3.88e-15  -5.7 4.81e-11    -  1.00e+00 1.00e+00h  1
#    5  3.1949593e-02 8.67e-19 4.15e-15  -8.6 5.95e-13    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.1949592916468497e-02    3.1949592916468497e-02
# Dual infeasibility......:   4.1515524199821352e-15    4.1515524199821352e-15
# Constraint violation....:   8.6736173798840355e-19    8.6736173798840355e-19
# Complementarity.........:   2.5059035597114338e-09    2.5059035597114338e-09
# Overall NLP error.......:   2.5059035597114338e-09    2.5059035597114338e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 6
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 6
# Number of Lagrangian Hessian evaluations             = 5
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.003
# Total CPU secs in NLP function evaluations           =      0.004
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  15.00us (  2.50us)  16.07us (  2.68us)         6
#        nlp_g  | 228.00us ( 38.00us) 231.87us ( 38.65us)         6
#     nlp_grad  | 100.00us (100.00us)  99.70us ( 99.70us)         1
#   nlp_grad_f  |  18.00us (  2.57us)  21.85us (  3.12us)         7
#   nlp_hess_l  |   2.67ms (533.20us)   2.68ms (536.77us)         5
#    nlp_jac_g  |   1.15ms (164.86us)   1.15ms (164.91us)         7
#        total  |   8.74ms (  8.74ms)   8.77ms (  8.77ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  3.1949593e-02 2.86e-04 1.49e-13  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.7875757e-02 3.07e-13 1.36e-07  -1.0 3.49e-04    -  9.93e-01 1.00e+00h  1
#    2  2.7875757e-02 4.34e-19 7.11e-15  -1.7 1.41e-06    -  1.00e+00 1.00e+00h  1
#    3  2.7875757e-02 6.51e-19 7.12e-15  -3.8 5.33e-09    -  1.00e+00 1.00e+00h  1
#    4  2.7875757e-02 4.34e-19 3.18e-15  -5.7 4.19e-11    -  1.00e+00 1.00e+00h  1
#    5  2.7875757e-02 1.30e-18 3.06e-15  -8.6 5.18e-13    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.7875757322571991e-02    2.7875757322571991e-02
# Dual infeasibility......:   3.0575568525604765e-15    3.0575568525604765e-15
# Constraint violation....:   1.3010426069826053e-18    1.3010426069826053e-18
# Complementarity.........:   2.5059035597073451e-09    2.5059035597073451e-09
# Overall NLP error.......:   2.5059035597073451e-09    2.5059035597073451e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 6
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 6
# Number of Lagrangian Hessian evaluations             = 5
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.004
# Total CPU secs in NLP function evaluations           =      0.004
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  17.00us (  2.83us)  17.65us (  2.94us)         6
#        nlp_g  | 236.00us ( 39.33us) 238.80us ( 39.80us)         6
#     nlp_grad  | 112.00us (112.00us) 111.78us (111.78us)         1
#   nlp_grad_f  |  26.00us (  3.71us)  24.75us (  3.54us)         7
#   nlp_hess_l  |   2.94ms (588.20us)   2.94ms (588.64us)         5
#    nlp_jac_g  |   1.24ms (177.14us)   1.24ms (177.41us)         7
#        total  |  10.07ms ( 10.07ms)  10.07ms ( 10.07ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.7875757e-02 2.70e-04 9.13e-14  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.4321459e-02 2.96e-13 1.35e-07  -1.0 3.46e-04    -  9.93e-01 1.00e+00h  1
#    2  2.4321459e-02 4.34e-19 7.11e-15  -1.7 1.30e-06    -  1.00e+00 1.00e+00h  1
#    3  2.4321459e-02 8.67e-19 4.74e-15  -3.8 4.59e-09    -  1.00e+00 1.00e+00h  1
#    4  2.4321459e-02 4.34e-19 4.59e-15  -5.7 3.62e-11    -  1.00e+00 1.00e+00h  1
#    5  2.4321459e-02 8.67e-19 2.71e-15  -8.6 4.48e-13    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.4321459273262729e-02    2.4321459273262729e-02
# Dual infeasibility......:   2.7077915376507583e-15    2.7077915376507583e-15
# Constraint violation....:   8.6736173798840355e-19    8.6736173798840355e-19
# Complementarity.........:   2.5059035597036050e-09    2.5059035597036050e-09
# Overall NLP error.......:   2.5059035597036050e-09    2.5059035597036050e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 6
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 6
# Number of Lagrangian Hessian evaluations             = 5
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.004
# Total CPU secs in NLP function evaluations           =      0.005
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  20.00us (  3.33us)  18.94us (  3.16us)         6
#        nlp_g  | 254.00us ( 42.33us) 255.23us ( 42.54us)         6
#     nlp_grad  | 123.00us (123.00us) 122.10us (122.10us)         1
#   nlp_grad_f  |  28.00us (  4.00us)  27.32us (  3.90us)         7
#   nlp_hess_l  |   3.05ms (610.40us)   3.05ms (609.76us)         5
#    nlp_jac_g  |   1.36ms (195.00us)   1.38ms (196.74us)         7
#        total  |  10.73ms ( 10.73ms)  10.60ms ( 10.60ms)         1

# %%
plot_trajectories_pendulum_on_cart(s_traj, a_traj, a_max, a_min)

# %% [markdown]
# ### 6.3 Closed Loop Simulation with Noise
#
# Introduce noise to your closed-loop simulation and compare the control performance.

# %%
N_steps = 100
N_horizon = 20

ocp_solver = OCPsolver(model, stage_cost, terminal_cost, N_horizon, a_max, -a_max)

s_traj = np.zeros((ns, N_steps+1))
a_traj = np.zeros((na, N_steps))

# generate noise trajectory
w_traj = 0.01*np.random.normal(size=(ns, N_steps))

s0 = np.array([0, np.pi, 0, 0])

# closed-loop simulation
s_traj[:, 0] = s0

for n in range(N_steps):
    s = s_traj[:, n]
    a = ocp_solver.solve(s)

    a_traj[:, n] = a
    s_traj[:, [n+1]] = model.simulate(s, a, w0=w_traj[:, [n]])
# Out:
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...
#  236  5.8879108e+05 2.13e-01 6.83e+03  -1.0 7.31e+01    -  8.49e-04 2.36e-01f  1
#  237  5.8870249e+05 2.13e-01 6.81e+03  -1.0 1.01e+02    -  6.20e-02 2.54e-03f  1
#  238  5.8867678e+05 2.12e-01 6.80e+03  -1.0 7.41e+01    -  4.07e-01 1.06e-03f  1
#  239  5.7949142e+05 3.00e-01 5.89e+03  -1.0 7.31e+01    -  4.45e-02 5.93e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240  5.7933627e+05 2.86e-01 5.62e+03  -1.0 1.04e+01    -  4.18e-01 4.63e-02f  1
#  241  5.7688688e+05 9.63e-03 3.13e+02  -1.0 6.82e+00    -  7.38e-03 1.00e+00f  1
#  242  5.7687889e+05 9.35e-03 3.04e+02  -1.0 9.66e+00    -  1.00e+00 2.90e-02f  1
#  243  5.7679067e+05 1.16e-03 4.10e+01  -1.0 9.42e+00    -  1.41e-01 1.00e+00f  1
#  244  5.7678956e+05 3.21e-04 1.14e+01  -1.7 2.14e-01    -  1.00e+00 7.23e-01f  1
#  245  5.7678907e+05 5.58e-08 1.48e-03  -2.5 5.94e-02    -  1.00e+00 1.00e+00f  1
#  246  5.7678904e+05 2.51e-12 2.85e-08  -5.7 1.30e-04    -  1.00e+00 1.00e+00f  1
#  247  5.7678904e+05 1.78e-15 7.28e-11  -8.6 8.86e-08    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 247
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.7678904045995011e+05    5.7678904045995011e+05
# Dual infeasibility......:   7.2759576141834259e-11    7.2759576141834259e-11
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Complementarity.........:   2.5098908315207534e-09    2.5098908315207534e-09
# Overall NLP error.......:   1.2325999769336967e-09    2.5098908315207534e-09
#
#
# Number of objective function evaluations             = 568
# Number of objective gradient evaluations             = 229
# Number of equality constraint evaluations            = 568
# Number of inequality constraint evaluations          = 568
# Number of equality constraint Jacobian evaluations   = 249
# Number of inequality constraint Jacobian evaluations = 249
# Number of Lagrangian Hessian evaluations             = 247
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.189
# Total CPU secs in NLP function evaluations           =      0.251
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.65ms (  2.91us)   1.67ms (  2.95us)       568
#        nlp_g  |  26.72ms ( 47.05us)  27.08ms ( 47.68us)       568
#     nlp_grad  | 124.00us (124.00us) 124.28us (124.28us)         1
#   nlp_grad_f  | 898.00us (  3.90us) 905.83us (  3.94us)       230
#   nlp_hess_l  | 164.71ms (669.56us) 165.80ms (674.00us)       246
#    nlp_jac_g  |  55.22ms (220.87us)  55.72ms (222.90us)       250
#        total  | 558.33ms (558.33ms) 560.60ms (560.60ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  5.7678904e+05 2.18e+00 7.92e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.4911198e+05 1.54e+00 2.89e+01  -1.0 5.12e+01    -  9.23e-02 2.93e-01f  1
#    2  5.3936934e+05 1.24e+00 2.31e+01  -1.0 1.81e+01    -  8.00e-02 1.91e-01f  1
#    3  5.1904507e+05 6.90e-01 1.18e+01  -1.0 2.45e+01    -  1.80e-01 4.45e-01f  1
#    4  5.1307014e+05 5.62e-01 9.57e+00  -1.0 2.67e+01    -  6.17e-01 1.85e-01f  1
#    5  4.8896480e+05 1.68e-01 2.49e+01  -1.0 4.09e+01    -  1.88e-01 7.01e-01f  1
#    6  4.8345236e+05 1.11e-01 1.76e+01  -1.0 2.66e+01    -  7.54e-01 3.39e-01f  1
#    7  4.7784151e+05 7.89e-03 2.39e+00  -1.0 7.45e+00    -  8.71e-01 1.00e+00f  1
#    8  4.7671347e+05 2.42e-03 4.28e-01  -1.0 3.98e+00    -  1.00e+00 8.72e-01f  1
#    9  4.7630828e+05 5.28e-04 1.74e-02  -1.7 2.30e+00    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.7620137e+05 5.71e-05 1.59e-03  -2.5 7.21e-01    -  1.00e+00 1.00e+00f  1
#   11  4.7618397e+05 2.29e-06 4.76e-05  -3.8 1.58e-01    -  1.00e+00 1.00e+00f  1
#   12  4.7618301e+05 8.44e-09 1.57e-07  -5.7 9.51e-03    -  1.00e+00 1.00e+00h  1
#   13  4.7618300e+05 6.61e-13 1.23e-11  -8.6 7.57e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 13
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.5786877639217903e+02    4.7618299605975108e+05
# Dual infeasibility......:   1.2288836614970933e-11    7.7213037661515884e-09
# Constraint violation....:   6.6080474425689317e-13    6.6080474425689317e-13
# Complementarity.........:   2.5456165191549742e-09    1.5994580310868177e-06
# Overall NLP error.......:   2.5456165191549742e-09    1.5994580310868177e-06
#
#
# Number of objective function evaluations             = 14
# Number of objective gradient evaluations             = 14
# Number of equality constraint evaluations            = 14
# Number of inequality constraint evaluations          = 14
# Number of equality constraint Jacobian evaluations   = 14
# Number of inequality constraint Jacobian evaluations = 14
# Number of Lagrangian Hessian evaluations             = 13
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.008
# Total CPU secs in NLP function evaluations           =      0.012
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  42.00us (  3.00us)  45.99us (  3.28us)        14
#        nlp_g  | 703.00us ( 50.21us) 706.28us ( 50.45us)        14
#     nlp_grad  | 167.00us (167.00us) 167.35us (167.35us)         1
#   nlp_grad_f  |  58.00us (  3.87us)  56.84us (  3.79us)        15
#   nlp_hess_l  |   8.53ms (656.38us)   8.60ms (661.38us)        13
#    nlp_jac_g  |   3.29ms (219.47us)   3.40ms (226.40us)        15
#        total  |  26.19ms ( 26.19ms)  26.36ms ( 26.36ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  4.7618300e+05 2.06e+00 5.53e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  4.5082776e+05 1.52e+00 3.02e+01  -1.0 5.68e+01    -  8.41e-02 2.65e-01f  1
#    2  4.0825437e+05 8.17e-02 9.21e+00  -1.0 1.68e+01    -  8.62e-02 1.00e+00f  1
#    3  3.9940497e+05 5.37e-02 5.48e+00  -1.0 2.20e+01    -  2.46e-01 4.04e-01f  1
#    4  3.9019375e+05 3.03e-02 1.10e+01  -1.0 2.28e+01    -  5.63e-01 1.00e+00f  1
#    5  3.8303248e+05 3.01e-02 5.70e+00  -1.0 2.73e+01    -  6.97e-01 6.07e-01f  1
#    6  3.8179673e+05 8.11e-03 5.74e-01  -1.0 1.03e+01    -  7.91e-01 8.58e-01f  1
#    7  3.8136509e+05 1.46e-03 5.60e-02  -1.0 6.43e+00    -  1.00e+00 1.00e+00f  1
#    8  3.8101862e+05 5.57e-04 1.07e-02  -1.7 1.75e+00    -  1.00e+00 1.00e+00f  1
#    9  3.8092874e+05 3.82e-05 9.67e-04  -2.5 5.33e-01    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.8091405e+05 1.47e-06 3.08e-05  -3.8 1.20e-01    -  1.00e+00 1.00e+00f  1
#   11  3.8091324e+05 4.92e-09 9.72e-08  -5.7 6.91e-03    -  1.00e+00 1.00e+00h  1
#   12  3.8091323e+05 4.61e-13 9.14e-12  -8.6 6.15e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.1703518933104942e+02    3.8091322921642737e+05
# Dual infeasibility......:   9.1375795818748884e-12    5.6408856511531045e-09
# Constraint violation....:   4.6096459982436500e-13    4.6096459982436500e-13
# Complementarity.........:   2.5332402030790705e-09    1.5638406412150645e-06
# Overall NLP error.......:   2.5332402030790705e-09    1.5638406412150645e-06
#
#
# Number of objective function evaluations             = 13
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 13
# Number of inequality constraint evaluations          = 13
# Number of equality constraint Jacobian evaluations   = 13
# Number of inequality constraint Jacobian evaluations = 13
# Number of Lagrangian Hessian evaluations             = 12
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.008
# Total CPU secs in NLP function evaluations           =      0.011
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  43.00us (  3.31us)  41.63us (  3.20us)        13
#        nlp_g  | 630.00us ( 48.46us) 634.49us ( 48.81us)        13
#     nlp_grad  | 131.00us (131.00us) 130.06us (130.06us)         1
#   nlp_grad_f  |  58.00us (  4.14us)  56.13us (  4.01us)        14
#   nlp_hess_l  |   7.82ms (651.75us)   7.87ms (655.43us)        12
#    nlp_jac_g  |   2.95ms (210.71us)   2.96ms (211.50us)        14
#        total  |  22.49ms ( 22.49ms)  22.57ms ( 22.57ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  3.8091323e+05 1.76e+00 3.92e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.5870761e+05 1.33e+00 3.19e+01  -1.0 6.30e+01    -  8.18e-02 2.44e-01f  1
#    2  3.1875533e+05 1.51e-01 1.65e+01  -1.0 2.57e+01    -  7.82e-02 1.00e+00f  1
#    3  3.0934606e+05 1.61e-02 5.31e+00  -1.0 1.67e+01    -  3.07e-01 1.00e+00f  1
#    4  3.0131126e+05 3.16e-02 1.40e+00  -1.0 2.26e+01    -  5.29e-01 1.00e+00f  1
#    5  2.9767814e+05 2.35e-02 2.15e-01  -1.0 2.16e+01    -  7.66e-01 3.72e-01f  1
#    6  2.9696393e+05 8.48e-03 3.39e+00  -1.0 1.33e+01    -  7.65e-01 1.00e+00f  1
#    7  2.9583395e+05 2.15e-03 4.79e-01  -1.0 6.02e+00    -  1.00e+00 9.46e-01f  1
#    8  2.9555157e+05 5.30e-04 9.45e-03  -1.7 1.88e+00    -  1.00e+00 1.00e+00f  1
#    9  2.9547560e+05 3.07e-05 6.24e-04  -2.5 4.52e-01    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.9546349e+05 9.03e-07 2.05e-05  -3.8 9.09e-02    -  1.00e+00 1.00e+00f  1
#   11  2.9546283e+05 2.61e-09 5.81e-08  -5.7 4.83e-03    -  1.00e+00 1.00e+00h  1
#   12  2.9546283e+05 2.77e-13 6.24e-12  -8.6 4.68e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.0431204774966596e+02    2.9546282563328889e+05
# Dual infeasibility......:   6.2385652199736796e-12    3.6550070854265145e-09
# Constraint violation....:   2.7711166694643907e-13    2.7711166694643907e-13
# Complementarity.........:   2.5230522076585300e-09    1.4781882325070642e-06
# Overall NLP error.......:   2.5230522076585300e-09    1.4781882325070642e-06
#
#
# Number of objective function evaluations             = 13
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 13
# Number of inequality constraint evaluations          = 13
# Number of equality constraint Jacobian evaluations   = 13
# Number of inequality constraint Jacobian evaluations = 13
# Number of Lagrangian Hessian evaluations             = 12
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.008
# Total CPU secs in NLP function evaluations           =      0.011
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  40.00us (  3.08us)  43.96us (  3.38us)        13
#        nlp_g  | 637.00us ( 49.00us) 640.09us ( 49.24us)        13
#     nlp_grad  | 134.00us (134.00us) 134.06us (134.06us)         1
#   nlp_grad_f  |  67.00us (  4.79us)  69.84us (  4.99us)        14
#   nlp_hess_l  |   7.90ms (658.50us)   8.00ms (666.94us)        12
#    nlp_jac_g  |   2.96ms (211.36us)   2.97ms (211.79us)        14
#        total  |  25.78ms ( 25.78ms)  25.94ms ( 25.94ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.9546283e+05 1.56e+00 3.57e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.7679224e+05 1.19e+00 3.51e+01  -1.0 6.89e+01    -  9.60e-02 2.35e-01f  1
#    2  2.3422214e+05 4.79e-01 1.45e+01  -1.0 4.15e+01    -  3.49e-02 1.00e+00f  1
#    3  2.2746747e+05 1.52e-02 1.26e+00  -1.0 1.20e+01    -  5.56e-01 1.00e+00f  1
#    4  2.2484913e+05 1.29e-02 1.88e+00  -1.0 1.34e+01    -  8.34e-01 1.00e+00f  1
#    5  2.2399203e+05 6.98e-03 2.53e-01  -1.0 1.14e+01    -  9.93e-01 1.00e+00f  1
#    6  2.2396775e+05 2.74e-04 2.22e-02  -1.0 3.08e+00    -  1.00e+00 1.00e+00h  1
#    7  2.2367803e+05 2.76e-04 6.60e-03  -2.5 1.17e+00    -  9.97e-01 1.00e+00f  1
#    8  2.2365744e+05 5.37e-06 1.64e-04  -3.8 2.63e-01    -  1.00e+00 1.00e+00f  1
#    9  2.2365668e+05 8.45e-09 2.54e-07  -5.7 1.11e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.2365667e+05 2.75e-13 7.47e-12  -8.6 5.17e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 10
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.1797150717187230e+02    2.2365667242768282e+05
# Dual infeasibility......:   7.4678041528386530e-12    3.9960241272587950e-09
# Constraint violation....:   2.7533531010703882e-13    2.7533531010703882e-13
# Complementarity.........:   2.5275149764299203e-09    1.3524739831296593e-06
# Overall NLP error.......:   2.5275149764299203e-09    1.3524739831296593e-06
#
#
# Number of objective function evaluations             = 11
# Number of objective gradient evaluations             = 11
# Number of equality constraint evaluations            = 11
# Number of inequality constraint evaluations          = 11
# Number of equality constraint Jacobian evaluations   = 11
# Number of inequality constraint Jacobian evaluations = 11
# Number of Lagrangian Hessian evaluations             = 10
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.007
# Total CPU secs in NLP function evaluations           =      0.009
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  40.00us (  3.64us)  36.08us (  3.28us)        11
#        nlp_g  | 526.00us ( 47.82us) 526.36us ( 47.85us)        11
#     nlp_grad  | 128.00us (128.00us) 128.01us (128.01us)         1
#   nlp_grad_f  |  48.00us (  4.00us)  48.40us (  4.03us)        12
#   nlp_hess_l  |   6.48ms (648.10us)   6.50ms (650.13us)        10
#    nlp_jac_g  |   2.50ms (208.50us)   2.51ms (209.26us)        12
#        total  |  19.34ms ( 19.34ms)  19.38ms ( 19.38ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.2365667e+05 1.18e+00 3.91e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.7639648e+05 2.28e-01 4.16e+01  -1.0 1.24e+01    -  5.55e-01 1.00e+00f  1
#    2  1.7031603e+05 4.24e-02 1.31e+00  -1.0 1.61e+01    -  1.06e-01 9.65e-01f  1
#    3  1.6958367e+05 1.24e-03 1.14e+00  -1.0 4.75e+00    -  8.83e-01 1.00e+00f  1
#    4  1.6924400e+05 2.99e-03 3.30e-01  -1.0 6.76e+00    -  9.96e-01 1.00e+00f  1
#    5  1.6908911e+05 1.64e-04 8.22e-02  -1.7 1.57e+00    -  1.00e+00 1.00e+00f  1
#    6  1.6903846e+05 2.19e-05 9.69e-03  -2.5 5.07e-01    -  1.00e+00 1.00e+00f  1
#    7  1.6902913e+05 1.85e-06 1.91e-04  -3.8 1.57e-01    -  1.00e+00 1.00e+00f  1
#    8  1.6902863e+05 7.54e-09 7.34e-07  -5.7 1.07e-02    -  1.00e+00 1.00e+00h  1
#    9  1.6902863e+05 4.56e-13 9.61e-11  -8.6 8.06e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 9
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.5983520277193662e+02    1.6902862960882671e+05
# Dual infeasibility......:   9.6122221293626353e-11    4.5152356453894934e-08
# Constraint violation....:   4.5563552930616424e-13    4.5563552930616424e-13
# Complementarity.........:   2.5745626591968913e-09    1.2093724982264197e-06
# Overall NLP error.......:   2.5745626591968913e-09    1.2093724982264197e-06
#
#
# Number of objective function evaluations             = 10
# Number of objective gradient evaluations             = 10
# Number of equality constraint evaluations            = 10
# Number of inequality constraint evaluations          = 10
# Number of equality constraint Jacobian evaluations   = 10
# Number of inequality constraint Jacobian evaluations = 10
# Number of Lagrangian Hessian evaluations             = 9
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.006
# Total CPU secs in NLP function evaluations           =      0.009
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  30.00us (  3.00us)  32.97us (  3.30us)        10
#        nlp_g  | 473.00us ( 47.30us) 472.82us ( 47.28us)        10
#     nlp_grad  | 120.00us (120.00us) 119.23us (119.23us)         1
#   nlp_grad_f  |  41.00us (  3.73us)  42.92us (  3.90us)        11
#   nlp_hess_l  |   6.00ms (666.11us)   6.05ms (672.11us)         9
#    nlp_jac_g  |   2.32ms (211.36us)   2.37ms (215.66us)        11
#        total  |  17.18ms ( 17.18ms)  17.31ms ( 17.31ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.6902863e+05 1.68e+00 2.97e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.5908516e+05 1.32e+00 3.23e+00  -1.0 2.02e+01    -  4.44e-01 2.15e-01f  1
#    2  1.3106703e+05 1.65e-01 2.04e+01  -1.0 2.15e+01    -  3.94e-02 8.97e-01f  1
#    3  1.2599025e+05 2.91e-03 3.99e+00  -1.0 3.14e+00    -  8.86e-01 1.00e+00f  1
#    4  1.2566731e+05 3.06e-03 3.11e-02  -1.0 5.43e+00    -  9.84e-01 1.00e+00f  1
#    5  1.2553450e+05 1.51e-04 5.85e-02  -1.7 1.46e+00    -  1.00e+00 1.00e+00f  1
#    6  1.2549255e+05 1.34e-05 9.61e-03  -2.5 4.27e-01    -  1.00e+00 1.00e+00f  1
#    7  1.2548490e+05 8.13e-07 5.00e-04  -3.8 1.16e-01    -  1.00e+00 1.00e+00f  1
#    8  1.2548448e+05 3.36e-09 1.94e-06  -5.7 7.75e-03    -  1.00e+00 1.00e+00h  1
#    9  1.2548447e+05 2.18e-13 1.41e-10  -8.6 5.98e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 9
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.0964107172132231e+02    1.2548447410476457e+05
# Dual infeasibility......:   1.4141932069833274e-10    5.7311289446946198e-08
# Constraint violation....:   2.1849189124623081e-13    2.1849189124623081e-13
# Complementarity.........:   2.5611583801057481e-09    1.0379295312471607e-06
# Overall NLP error.......:   2.5611583801057481e-09    1.0379295312471607e-06
#
#
# Number of objective function evaluations             = 10
# Number of objective gradient evaluations             = 10
# Number of equality constraint evaluations            = 10
# Number of inequality constraint evaluations          = 10
# Number of equality constraint Jacobian evaluations   = 10
# Number of inequality constraint Jacobian evaluations = 10
# Number of Lagrangian Hessian evaluations             = 9
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.006
# Total CPU secs in NLP function evaluations           =      0.008
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  30.00us (  3.00us)  33.32us (  3.33us)        10
#        nlp_g  | 459.00us ( 45.90us) 460.86us ( 46.09us)        10
#     nlp_grad  | 119.00us (119.00us) 117.97us (117.97us)         1
#   nlp_grad_f  |  45.00us (  4.09us)  42.48us (  3.86us)        11
#   nlp_hess_l  |   5.75ms (638.33us)   5.79ms (642.94us)         9
#    nlp_jac_g  |   2.20ms (199.91us)   2.21ms (200.74us)        11
#        total  |  17.09ms ( 17.09ms)  17.15ms ( 17.15ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.2548447e+05 1.65e+00 3.53e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.0055269e+05 2.36e-01 7.89e+00  -1.0 1.86e+01    -  4.51e-01 8.57e-01f  1
#    2  9.5573280e+04 1.10e-02 1.94e+01  -1.0 1.01e+01    -  8.34e-01 1.00e+00f  1
#    3  9.4843877e+04 9.49e-03 1.46e+00  -1.0 1.12e+01    -  9.04e-01 1.00e+00f  1
#    4  9.4731457e+04 4.89e-04 4.58e-02  -1.0 3.74e+00    -  1.00e+00 1.00e+00f  1
#    5  9.4670873e+04 1.39e-04 5.38e-02  -1.7 1.15e+00    -  1.00e+00 1.00e+00f  1
#    6  9.4646517e+04 1.61e-05 1.27e-02  -2.5 3.67e-01    -  1.00e+00 1.00e+00f  1
#    7  9.4640921e+04 3.70e-07 1.14e-03  -3.8 6.08e-02    -  1.00e+00 1.00e+00f  1
#    8  9.4640565e+04 2.67e-09 6.40e-06  -5.7 7.77e-03    -  1.00e+00 1.00e+00h  1
#    9  9.4640562e+04 1.31e-13 3.86e-10  -8.6 4.23e-05    -  1.00e+00 1.00e+00h  1
#
# ...
#   nlp_grad_f  |  32.00us (  4.00us)  30.10us (  3.76us)         8
#   nlp_hess_l  |   3.69ms (614.50us)   3.71ms (617.81us)         6
#    nlp_jac_g  |   1.56ms (194.50us)   1.55ms (193.98us)         8
#        total  |  11.95ms ( 11.95ms)  11.93ms ( 11.93ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  3.6626996e+00 3.97e-02 8.23e-13  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.5085054e+00 1.39e-06 1.66e-02  -1.0 8.21e-01    -  9.70e-01 1.00e+00h  1
#    2  6.5066056e+00 2.86e-10 1.04e-05  -1.0 1.83e-02    -  1.00e+00 1.00e+00h  1
#    3  6.5066054e+00 3.14e-15 1.37e-10  -2.5 5.97e-05    -  1.00e+00 1.00e+00h  1
#    4  6.5066054e+00 1.39e-17 8.53e-14  -3.8 9.80e-07    -  1.00e+00 1.00e+00h  1
#    5  6.5066054e+00 9.97e-18 1.10e-13  -5.7 5.40e-08    -  1.00e+00 1.00e+00h  1
#    6  6.5066054e+00 1.04e-17 7.82e-14  -8.6 6.69e-10    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 6
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.7849978038971206e+00    6.5066054252602639e+00
# Dual infeasibility......:   7.8159700933611020e-14    1.8260493183144337e-13
# Constraint violation....:   1.0408340855860843e-17    1.0408340855860843e-17
# Complementarity.........:   2.5059035961353449e-09    5.8545561188513429e-09
# Overall NLP error.......:   2.5059035961353449e-09    5.8545561188513429e-09
#
#
# Number of objective function evaluations             = 7
# Number of objective gradient evaluations             = 7
# Number of equality constraint evaluations            = 7
# Number of inequality constraint evaluations          = 7
# Number of equality constraint Jacobian evaluations   = 7
# Number of inequality constraint Jacobian evaluations = 7
# Number of Lagrangian Hessian evaluations             = 6
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.004
# Total CPU secs in NLP function evaluations           =      0.006
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  25.00us (  3.57us)  23.39us (  3.34us)         7
#        nlp_g  | 305.00us ( 43.57us) 305.06us ( 43.58us)         7
#     nlp_grad  | 120.00us (120.00us) 120.29us (120.29us)         1
#   nlp_grad_f  |  32.00us (  4.00us)  30.65us (  3.83us)         8
#   nlp_hess_l  |   3.92ms (652.67us)   3.93ms (655.69us)         6
#    nlp_jac_g  |   1.64ms (205.50us)   1.64ms (205.15us)         8
#        total  |  12.16ms ( 12.16ms)  12.10ms ( 12.10ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.5066054e+00 9.51e-02 2.98e-12  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.7121078e+01 5.08e-05 1.86e+00  -1.0 1.83e+00    -  9.45e-01 1.00e+00h  1
#    2  5.7158659e+01 2.73e-09 1.97e-04  -1.0 3.91e-02    -  1.00e+00 1.00e+00h  1
#    3  5.7158657e+01 7.99e-14 6.71e-09  -2.5 2.25e-04    -  1.00e+00 1.00e+00h  1
#    4  5.7158657e+01 5.55e-17 2.76e-12  -3.8 3.97e-06    -  1.00e+00 1.00e+00h  1
#    5  5.7158657e+01 5.55e-17 2.56e-13  -5.7 2.19e-07    -  1.00e+00 1.00e+00h  1
#    6  5.7158657e+01 5.55e-17 4.26e-13  -8.6 2.71e-09    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 6
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.0220186905047299e+01    5.7158656806783164e+01
# Dual infeasibility......:   4.2632564145606011e-13    8.0635507333175068e-13
# Constraint violation....:   5.5511151231257827e-17    5.5511151231257827e-17
# Complementarity.........:   2.5059037160099912e-09    4.7396824825836902e-09
# Overall NLP error.......:   2.5059037160099912e-09    4.7396824825836902e-09
#
#
# Number of objective function evaluations             = 7
# Number of objective gradient evaluations             = 7
# Number of equality constraint evaluations            = 7
# Number of inequality constraint evaluations          = 7
# Number of equality constraint Jacobian evaluations   = 7
# Number of inequality constraint Jacobian evaluations = 7
# Number of Lagrangian Hessian evaluations             = 6
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.004
# Total CPU secs in NLP function evaluations           =      0.006
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  23.00us (  3.29us)  23.43us (  3.35us)         7
#        nlp_g  | 306.00us ( 43.71us) 308.11us ( 44.02us)         7
#     nlp_grad  | 110.00us (110.00us) 110.52us (110.52us)         1
#   nlp_grad_f  |  31.00us (  3.87us)  31.90us (  3.99us)         8
#   nlp_hess_l  |   3.86ms (643.00us)   3.87ms (645.05us)         6
#    nlp_jac_g  |   1.63ms (203.88us)   1.63ms (204.28us)         8
#        total  |  12.78ms ( 12.78ms)  12.65ms ( 12.65ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  5.7158657e+01 1.92e-01 2.22e-12  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.5351809e+00 4.06e-05 1.22e+00  -1.0 3.54e+00    -  8.94e-01 1.00e+00f  1
#    2  6.4966997e+00 1.10e-08 5.13e-04  -1.0 9.44e-02    -  1.00e+00 1.00e+00f  1
#    3  6.4966957e+00 3.54e-13 1.12e-08  -2.5 7.32e-04    -  1.00e+00 1.00e+00h  1
#    4  6.4966957e+00 2.78e-17 1.14e-13  -3.8 1.35e-06    -  1.00e+00 1.00e+00h  1
#    5  6.4966957e+00 2.78e-17 2.84e-14  -5.7 8.61e-08    -  1.00e+00 1.00e+00h  1
#    6  6.4966957e+00 5.55e-17 1.87e-14  -8.6 1.07e-09    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 6
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.4227934857948348e+00    6.4966957063533792e+00
# Dual infeasibility......:   1.8651746813702630e-14    8.5166768508838577e-14
# Constraint violation....:   5.5511151231257827e-17    5.5511151231257827e-17
# Complementarity.........:   2.5059036149566817e-09    1.1442344527413768e-08
# Overall NLP error.......:   2.5059036149566817e-09    1.1442344527413768e-08
#
#
# Number of objective function evaluations             = 7
# Number of objective gradient evaluations             = 7
# Number of equality constraint evaluations            = 7
# Number of inequality constraint evaluations          = 7
# Number of equality constraint Jacobian evaluations   = 7
# Number of inequality constraint Jacobian evaluations = 7
# Number of Lagrangian Hessian evaluations             = 6
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.005
# Total CPU secs in NLP function evaluations           =      0.006
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  22.00us (  3.14us)  23.96us (  3.42us)         7
#        nlp_g  | 297.00us ( 42.43us) 300.57us ( 42.94us)         7
#     nlp_grad  | 113.00us (113.00us) 113.53us (113.53us)         1
#   nlp_grad_f  |  31.00us (  3.88us)  30.81us (  3.85us)         8
#   nlp_hess_l  |   3.86ms (643.83us)   3.89ms (647.79us)         6
#    nlp_jac_g  |   1.57ms (196.50us)   1.57ms (195.72us)         8
#        total  |  13.48ms ( 13.48ms)  13.52ms ( 13.52ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.4966957e+00 4.40e-02 1.23e-12  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.7250403e+01 4.66e-06 6.11e-02  -1.0 1.77e+00    -  9.46e-01 1.00e+00h  1
#    2  2.7233357e+01 4.56e-09 1.20e-04  -1.0 5.62e-02    -  1.00e+00 1.00e+00f  1
#    3  2.7233352e+01 1.17e-13 3.61e-09  -2.5 3.16e-04    -  1.00e+00 1.00e+00h  1
#    4  2.7233352e+01 2.08e-17 4.62e-13  -3.8 3.57e-06    -  1.00e+00 1.00e+00h  1
#    5  2.7233352e+01 2.08e-17 1.80e-13  -5.7 1.95e-07    -  1.00e+00 1.00e+00h  1
#    6  2.7233352e+01 2.43e-17 1.63e-13  -8.6 2.42e-09    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 6
#
#                                    (scaled)                 (unscaled)
# Objective...............:   8.7890683178790496e+00    2.7233352417362813e+01
# Dual infeasibility......:   1.6298074001497298e-13    5.0500368975871529e-13
# Constraint violation....:   2.4286128663675299e-17    2.4286128663675299e-17
# Complementarity.........:   2.5059036965042278e-09    7.7646635596229261e-09
# Overall NLP error.......:   2.5059036965042278e-09    7.7646635596229261e-09
#
#
# Number of objective function evaluations             = 7
# Number of objective gradient evaluations             = 7
# Number of equality constraint evaluations            = 7
# Number of inequality constraint evaluations          = 7
# Number of equality constraint Jacobian evaluations   = 7
# Number of inequality constraint Jacobian evaluations = 7
# Number of Lagrangian Hessian evaluations             = 6
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.004
# Total CPU secs in NLP function evaluations           =      0.005
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  22.00us (  3.14us)  21.71us (  3.10us)         7
#        nlp_g  | 286.00us ( 40.86us) 285.75us ( 40.82us)         7
#     nlp_grad  | 109.00us (109.00us) 109.27us (109.27us)         1
#   nlp_grad_f  |  27.00us (  3.38us)  29.14us (  3.64us)         8
#   nlp_hess_l  |   3.64ms (607.17us)   3.67ms (612.35us)         6
#    nlp_jac_g  |   1.51ms (188.75us)   1.53ms (190.69us)         8
#        total  |  11.56ms ( 11.56ms)  11.59ms ( 11.59ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      384
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:      170
#
# Total number of variables............................:      104
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       84
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:       20
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.7233352e+01 1.51e-01 2.06e-12  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.9488697e+01 6.95e-06 8.35e-02  -1.0 6.53e-01    -  9.75e-01 1.00e+00h  1
#    2  5.9487889e+01 1.25e-09 2.86e-05  -1.0 2.43e-02    -  1.00e+00 1.00e+00h  1
#    3  5.9487886e+01 2.03e-13 2.71e-09  -2.5 2.70e-04    -  1.00e+00 1.00e+00h  1
#    4  5.9487886e+01 1.25e-16 1.81e-12  -3.8 6.22e-06    -  1.00e+00 1.00e+00h  1
#    5  5.9487886e+01 5.55e-17 2.63e-13  -5.7 3.42e-07    -  1.00e+00 1.00e+00h  1
#    6  5.9487886e+01 4.16e-17 1.42e-13  -8.6 4.25e-09    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 6
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.6285956327788490e+01    5.9487886251526767e+01
# Dual infeasibility......:   1.4210854715202004e-13    5.1908140475144261e-13
# Constraint violation....:   4.1633363423443370e-17    4.1633363423443370e-17
# Complementarity.........:   2.5059037983771289e-09    9.1533415118380223e-09
# Overall NLP error.......:   2.5059037983771289e-09    9.1533415118380223e-09
#
#
# Number of objective function evaluations             = 7
# Number of objective gradient evaluations             = 7
# Number of equality constraint evaluations            = 7
# Number of inequality constraint evaluations          = 7
# Number of equality constraint Jacobian evaluations   = 7
# Number of inequality constraint Jacobian evaluations = 7
# Number of Lagrangian Hessian evaluations             = 6
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.004
# Total CPU secs in NLP function evaluations           =      0.006
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  23.00us (  3.29us)  23.03us (  3.29us)         7
#        nlp_g  | 302.00us ( 43.14us) 301.83us ( 43.12us)         7
#     nlp_grad  | 111.00us (111.00us) 111.45us (111.45us)         1
#   nlp_grad_f  |  32.00us (  4.00us)  31.90us (  3.99us)         8
#   nlp_hess_l  |   3.79ms (631.83us)   3.84ms (639.72us)         6
#    nlp_jac_g  |   1.56ms (194.88us)   1.56ms (195.36us)         8
#        total  |  12.70ms ( 12.70ms)  12.77ms ( 12.77ms)         1

# %%
plot_trajectories_pendulum_on_cart(s_traj, a_traj, a_max, a_min)

# %% [markdown]
# ### 6.4 Real-time iterations
# Since solving nonlinear optimization problems online can be rather computationally demanding, schemes are present in the literature that exploit approximate solutions. In the following, you will implement the so-called Real-Time Iteration (RTI) scheme, which relies on the solution of a single convex quadratic problem (QP) that locally approximates the above optimal control problem. In order to do so, consider the following formulation:
# <img src="imgs/qp.png" alt="nlp" width="450"/>
#
# where $A_i = \frac{\partial F}{\partial s}(\tilde{s}_i, \tilde{a}_i)$, $B_i = \frac{\partial F}{\partial a} (\tilde{s}_i, \tilde{a}_i) $ and where $(\tilde{s},\,\tilde{a})$ represent the linearization point at which the local approximation is computed. Notice that the nonlinear discretized dynamics have been replaced by a local time-varying model obtained by computing a Taylor series expansion of first order of the RK4 equations. Once a solution to the QP is obtained, the first control input is applied to the system and the linearization point is updated using the obtained state-input vector.
#
# Implement the RTI scheme in CasADi by replacing the NLP solver that you obtain with  `nlpsol('solver', 'ipopt', self.ocp)` by a QP solver, `qpsol('solver', 'qpoases', self.ocp)`.
# The QP solver linearizes the NLP at the initial guess that you provide and solves the resulting QP, which has the form given above.
#
# For the first OCP, initialize the $\theta$ component of your initial guess for the state trajectory with `np.linspace(np.pi, 0, N_horizon)`. Discuss why you need this initialization.

# %%
class  RTI_OCPsolver:

    def __init__(self, model, stage_cost, terminal_cost, N, a_max, a_min):

        self.N = N
        self.model = model

        ns = model.ns
        na = model.na

        # setup OCP

        # optimization variables
        s_traj = SX.sym('s_traj', ns*(N+1), 1)
        a_traj = SX.sym('a_traj', na*N, 1)

        # split trajectories to obtain x and u for each stage
        s_ns = vertsplit(s_traj, np.arange(0, ns*(N+1)+1, ns))
        a_ns = vertsplit(a_traj, np.arange(0, na*N+1, na))

        # initial state (will be a parameter of the optimization problem)
        s0_bar = SX.sym('s0_bar', ns, 1)

        cost = 0

        # initial constraint
        constraints = [s_ns[0] - s0_bar]

        for n in range(N):
            s0 = s_ns[n]
            a0 = a_ns[n]
            s1 = s_ns[n+1]
            
            f0 = model.f(s0, a0)

            # add stage cost to objective
            cost += stage_cost(s0, a0)

            # add continuity contraint
            constraints += [s1-f0] 
        
        # add terminal cost
        cost += terminal_cost(s1)

        # continuity constraints and bounds on u
        constraints = vertcat(*constraints, a_traj)

        # set upper and lower bounds 
        # zeros for continuity constraints, a_max/a_min fro control bounds
        self.ubg = vertcat(np.zeros((ns*(N+1))), a_max*np.ones((N*na)))
        self.lbg = vertcat(np.zeros((ns*(N+1))), a_min*np.ones((N*na)))

        self.ocp = {'f': cost, 'x': vertcat(s_traj, a_traj), 'g': constraints, 'p':s0_bar}
        self.solver = qpsol('solver', 'qpoases', self.ocp)

        # initialize current solution guess
        self.s_current = np.zeros((ns*(N+1), 1))
        self.a_current = np.zeros((na*N, 1))


    def solve(self, s0, s_traj_init=None, a_traj_init=None):

        if s_traj_init is not None:
            self.s_current = s_traj_init

        if a_traj_init is not None:
            self.a_current = a_traj_init

        # solve the NLP
        sol = self.solver(x0=vertcat(self.s_current, self.a_current), lbg=self.lbg, ubg=self.ubg, p=s0)
        
        w_opt = sol['x'].full()

        s_opt = w_opt[:(self.N+1)*self.model.ns]
        a_opt = w_opt[(self.N+1)*self.model.ns:]

        cost = sol['f'].full()

        self.s_current = s_opt
        self.a_current = a_opt

        a0_opt = a_opt[:self.model.na]
        return a0_opt


    def reset(self):
        self.s_current = np.zeros((self.model.ns*(self.N+1), 1))
        self.a_current = np.zeros((self.model.na*self.N, 1))

# %%
N_steps = 100
N_horizon = 20

ocp_solver = RTI_OCPsolver(model, stage_cost, terminal_cost, N_horizon, a_max, -a_max)

s_traj = np.zeros((ns, N_steps+1))
a_traj = np.zeros((na, N_steps))

s0 = np.array([0, np.pi, 0, 0])

# initial guess
s_traj_init = np.zeros((ns, N_horizon+1))
s_traj_init[1, :] = np.linspace(np.pi, 0, N_horizon+1)

s_traj_init = np.reshape(s_traj_init, ((N_horizon+1)*ns,), order='F')
a_traj_init = ocp_solver.a_current

# closed-loop simulation
s_traj[:, 0] = s0

for n in range(N_steps):
    s = s_traj[:, n]
    
#         FILL IN YOUR CODE HERE
    
    a = ocp_solver.solve(s, s_traj_init, ocp_solver.a_current)
    s_traj_init = ocp_solver.s_current

    a_traj[:, n] = a
    s_traj[:, [n+1]] = model.simulate(s, a)
# Out:
# CasADi - 2022-10-30 15:48:33 WARNING(".../casadi/core/plugin_interface.hpp:322: Assertion "handle!=nullptr" failed:
# PluginInterface::load_plugin: Cannot load shared library 'libcasadi_conic_qpoases.dylib':
#    (
#     Searched directories: 1. casadipath from GlobalOptions
#                           2. CASADIPATH env var
#                           3. PATH env var (Windows)
#                           4. LD_LIBRARY_PATH env var (Linux)
#                           5. DYLD_LIBRARY_PATH env var (osx)
#     A library may be 'not found' even if the file exists:
#           * library is not compatible (different compiler/bitness)
#           * the dependencies are not found
#    )
#   Tried '/Users/seunghyeonbang/anaconda3/envs/mpc_rl/lib/python3.8/site-packages/casadi' :
#     Error code: dlopen(/Users/seunghyeonbang/anaconda3/envs/mpc_rl/lib/python3.8/site-packages/casadi/libcasadi_conic_qpoases.dylib, 0x0005): Library not loaded: '@rpath/libmkl_intel_lp64.dylib'
#   Referenced from: '/Users/seunghyeonbang/anaconda3/envs/mpc_rl/lib/python3.8/site-pac... truncated") [.../casadi/core/plugin_interface.hpp:171]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [12], line 4
#       1 N_steps = 100
#       2 N_horizon = 20
# ----> 4 ocp_solver = RTI_OCPsolver(model, stage_cost, terminal_cost, N_horizon, a_max, -a_max)
#       6 s_traj = np.zeros((ns, N_steps+1))
#       7 a_traj = np.zeros((na, N_steps))
#
# Cell In [11], line 54, in RTI_OCPsolver.__init__(self, model, stage_cost, terminal_cost, N, a_max, a_min)
#      51 self.lbg = vertcat(np.zeros((ns*(N+1))), a_min*np.ones((N*na)))
#      53 self.ocp = {'f': cost, 'x': vertcat(s_traj, a_traj), 'g': constraints, 'p':s0_bar}
# ---> 54 self.solver = qpsol('solver', 'qpoases', self.ocp)
#      56 # initialize current solution guess
#      57 self.s_current = np.zeros((ns*(N+1), 1))
#
# File ~/anaconda3/envs/mpc_rl/lib/python3.8/site-packages/casadi/casadi.py:15649, in qpsol(*args)
#   15639 def qpsol(*args) -> "casadi::Function":
#   15640     """
#   15641
#   15642
#    (...)
#   15647
#   15648     """
# > 15649     return _casadi.qpsol(*args)
#
# RuntimeError: .../casadi/core/plugin_interface.hpp:417: Plugin 'qpoases' is not found.

# %%
plot_trajectories_pendulum_on_cart(s_traj, a_traj, a_max, a_min)

# %% [markdown]
# ### 6.4 Optional: acados
#
# If you have `acados` installed, you can solve the same OCP with `acados`.

# %%
from acados_template import AcadosModel
from casadi import SX, vertcat, sin, cos, Function

model_name = 'pendulum_ode'

model_acados = AcadosModel()

model_acados.f_expl_expr = s_dot
model_acados.x = s_expr
model_acados.u = a_expr
model_acados.name = model_name

# %%
import scipy.linalg
from acados_template import AcadosOcp, AcadosOcpSolver

# create ocp object to formulate the OCP
ocp = AcadosOcp()

# set model
ocp.model = model_acados

N_horizon = 20
Tf = N_horizon*dt
nx = ns
nu = na
ny = nx + nu
ny_e = nx
N = 20

# set dimensions
ocp.dims.N = N_horizon

# set cost module
ocp.cost.cost_type = 'EXTERNAL'
ocp.cost.cost_type_e = 'EXTERNAL'

ocp.model.cost_expr_ext_cost = stage_cost_expr
ocp.model.cost_expr_ext_cost_e = terminal_cost_expr


# set constraints
s0 = np.array([0, np.pi, 0, 0])
ocp.constraints.constr_type = 'BGH'
ocp.constraints.lbu = np.array([a_min])
ocp.constraints.ubu = np.array([a_max])
ocp.constraints.x0 = s0
ocp.constraints.idxbu = np.array([0])

ocp.solver_options.qp_solver = 'PARTIAL_CONDENSING_HPIPM' # FULL_CONDENSING_QPOASES
ocp.solver_options.hessian_approx = 'GAUSS_NEWTON'
ocp.solver_options.integrator_type = 'ERK'
ocp.solver_options.nlp_solver_type = 'SQP' # SQP_RTI

# set prediction horizon
ocp.solver_options.tf = Tf

acados_ocp_solver = AcadosOcpSolver(ocp, json_file = 'acados_ocp_' + model.name + '.json')

s_traj = np.zeros((ns, N_steps+1))
a_traj = np.zeros((na, N_steps))

# generate noise trajectory
w_traj = 0.0*np.random.normal(size=(ns, N_steps))

# initial guess
s_traj_init = np.zeros((ns, N_horizon+1))
s_traj_init[1, :] = np.linspace(np.pi, 0, N_horizon+1)


for i in range(N_horizon+1):
    acados_ocp_solver.set(i, "x", s_traj_init[:, i])

# closed-loop simulation
s_traj[:, 0] = s0

for n in range(N_steps):

    s = s_traj[:, n]
    
    # solve ocp
    acados_ocp_solver.set(0, "lbx", s)
    acados_ocp_solver.set(0, "ubx", s)

    status = acados_ocp_solver.solve()

    if status != 0:
        raise Exception('acados acados_ocp_solver returned status {}. Exiting.'.format(status))

    a = acados_ocp_solver.get(0, "u")
    a_traj[:, n] = a
    s_traj[:, [n+1]] = model.simulate(s, a, w0=w_traj[:, [n]])

# %%
plot_trajectories_pendulum_on_cart(s_traj, a_traj, a_max, a_min)
